# %% [markdown]
# # Notebook 09 — Paper Reading Session
#
# **Module:** 07 — Biochemistry and Molecular Biology
# **Notebook:** 09 of 10
# **Time estimate:** 2–3 hours (all three passes)
#
# > **Three-Pass Method:** do not skip to Pass 3. The discipline of Pass 1 (title/abstract/
# > figures only) and Pass 2 (read in order, mark fuzzy points) is what makes
# > Pass 3 (reconstruct unaided) possible.

# %% [markdown]
# ---
# ## Paper metadata
#
# | Field | Entry |
# |-------|-------|
# | **Title** | *(fill in)* |
# | **Authors** | *(fill in)* |
# | **Journal** | *(fill in)* |
# | **Year** | *(fill in)* |
# | **DOI** | *(fill in — cite, don't upload PDF)* |
# | **Why this paper** | *(fill in: how does it connect to this module?)* |
#
# ---
#
# ## Suggested papers for this session
#
# Pick one. Difficulty ordered easy → hard.
#
# 1. **Michaelis & Menten (1913)** — English translation by Goody & Johnson (2011),
#    Biochemistry, DOI: 10.1021/bi201284u. Historic; equations will be familiar after NB03.
#
# 2. **Briggs & Haldane (1925)** — A note on the kinetics of enzyme action,
#    Biochemical Journal, DOI: 10.1042/bj0190338. Short (2 pages); the steady-state
#    derivation. Pass-3 reconstruction: derive it yourself after reading.
#
# 3. **Crick (1970)** — Central Dogma of Molecular Biology, Nature,
#    DOI: 10.1038/227561a0. 4 pages; foundational; connects to Modules 05/07.

# %% [markdown]
# ---
# ## Pass 1 — Skim (5–10 minutes)
#
# Read: title, abstract, section headings, figures and captions only. No deep reading.
#
# **What is this paper claiming?**
# > *(1–2 sentences)*
#
# **What are the key figures?**
# > *(list 2–3 figures and what they show at the headline level)*
#
# **Is this Pass-1 sufficient for your current purposes, or do you need to continue?**
# > *(decision point — skip to Pass 3 if you already know the content well)*

# %% [markdown]
# ---
# ## Pass 2 — Intent (45–90 minutes)
#
# Read in order. Mark every fuzzy point below without interrupting your reading to
# resolve it.
#
# **What is the key method or result?**
# > *(2–3 sentences)*
#
# **What is the evidence base?**
# > *(experimental approach, sample sizes, controls)*
#
# **Fuzzy points — things I didn't fully understand during Pass 2:**
#
# | # | Fuzzy point | Source (section/equation/figure) |
# |---|------------|----------------------------------|
# | 1 | | |
# | 2 | | |
# | 3 | | |

# %% [markdown]
# ---
# ## Pass 3 — Reconstruct (60–120 minutes, increasingly unaided)
#
# **Instructions:** Close the paper. In the cells below, reconstruct the core method
# or derivation from memory. For the Briggs-Haldane paper, derive the MM equation
# from steady-state assumption. For Michaelis-Menten (1913), reconstruct the
# equilibrium assumption and compare to the Briggs-Haldane version.
#
# **Succeeded unaided?** [ ] Yes  [ ] No — looked up: ___________

# %%
# Pass 3: Reconstruct the core mathematical/algorithmic result from memory.
# For enzyme kinetics papers:
#   - Write out the derivation as comments
#   - Implement the final result as code
#   - Show it reproduces the paper's key figure

import numpy as np
import matplotlib.pyplot as plt

# Example: Briggs-Haldane steady-state MM derivation (implement from memory)
# E + S <-> ES -> E + P
# Steady state: d[ES]/dt = 0
# k1[E][S] = (k-1 + kcat)[ES]
# Define Km = (k-1 + kcat)/k1
# [E]_total = [E] + [ES]
# => [ES] = [E]_total * [S] / (Km + [S])
# v = kcat * [ES] = Vmax * [S] / (Km + [S])

# Your reconstruction here:

# %% [markdown]
# ---
# ## Paper note — log entry for `paper-notes/`
#
# Copy this section to `paper-notes/[author]_[year].md` after completing all three passes.
#
# **One-sentence summary:**
# > *(fill in)*
#
# **Why I read this / what question it answered:**
# > *(fill in)*
#
# **What I would cite this paper for:**
# > *(fill in)*
#
# **Pass-3 success:** [ ] Yes, unaided  [ ] No
#
# **Date:**
#
# ---
# ## Track A connection
#
# > *[If you were handed this paper in an interview and asked to explain it in 2 minutes,
# > what would you say? Write that explanation now. Then practice saying it aloud.]*
#
# ---
# *Next: `10_module_assessment.ipynb`*
