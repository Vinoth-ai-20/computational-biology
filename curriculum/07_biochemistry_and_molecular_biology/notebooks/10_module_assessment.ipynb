# %% [markdown]
# # Notebook 10 — Module 07 Assessment
#
# **Module:** 07 — Biochemistry and Molecular Biology
# **Notebook:** 10 of 10 (final)
# **Passing threshold:** 24/30 points (80%)
# **Time limit:** 75 minutes
# **Rules:** Sections A and B are closed-notebook. Section C may use module resources.
#
# ---
#
# > **Instructions:**
# > 1. Complete Section A (conceptual) in markdown cells — plain English, no code.
# > 2. Complete Section B (implementation) from memory, in the empty code cells.
# > 3. Section C (applied) may use any module resources.
# > 4. Section D (interview) — speak as if to a hiring panel.

# %% [markdown]
# ---
# ## Section A — Conceptual Questions (12 points, 2 pts each)
#
# **A1.** What does Km represent physically? Does a lower Km mean higher or lower
# affinity for the substrate?
#
# > *[Your answer]*
#
# ---
#
# **A2.** How does competitive inhibition differ from non-competitive inhibition?
# What happens to Km and Vmax in each case?
#
# > *[Your answer]*
#
# ---
#
# **A3.** What is the error rate of DNA polymerase (a) before proofreading, (b) after
# proofreading, and (c) after mismatch repair? Which disease results from defective MMR?
#
# > *[Your answer]*
#
# ---
#
# **A4.** Why does the lagging strand require Okazaki fragments? What enzyme removes
# the RNA primer?
#
# > *[Your answer]*
#
# ---
#
# **A5.** What is the GT-AG rule? Why does this matter for RNA-seq alignment?
#
# > *[Your answer]*
#
# ---
#
# **A6.** Name three types of post-translational modification, the residues they target,
# and one biological function of each.
#
# > *[Your answer]*

# %% [markdown]
# ---
# ## Section B — Implementation (12 points)
#
# ### B1 — `michaelis_menten(S, Vmax, Km)` and `competitive_inhibition()` [5 points]
#
# Implement both from memory. Verify:
# - `michaelis_menten(2.0, 10.0, 2.0)` → 5.0 (exactly Vmax/2 at [S]=Km)
# - `competitive_inhibition(2.0, 10.0, 2.0, 5.0, 2.5)` → lower than MM at same [S]

# %%
import numpy as np
import matplotlib.pyplot as plt

def michaelis_menten(S, Vmax, Km):
    pass  # TODO — from memory

def competitive_inhibition(S, Vmax, Km, I, Ki):
    pass  # TODO — from memory

# Tests
print("B1 tests:")
v1 = michaelis_menten(2.0, 10.0, 2.0)
print(f"  MM at [S]=Km: {v1}  (expected: 5.0)")
v2 = competitive_inhibition(2.0, 10.0, 2.0, 5.0, 2.5)
print(f"  Competitive inhibition: {v2}  (expected < 5.0)")

# %% [markdown]
# ### B2 — `molecular_weight(seq)` [3 points]
#
# Implement from memory. Verify: 'ACDEFG' → reasonable molecular weight (≈ 634 Da).

# %%
# Provide your own AA_MW dict — from memory
def molecular_weight(seq: str) -> float:
    pass  # TODO — from memory

print("B2 tests:")
mw = molecular_weight('ACDEFG')
print(f"  MW('ACDEFG') = {mw:.1f} Da  (expected ≈ 634–670 Da)")

# %% [markdown]
# ### B3 — MM kinetics figure [4 points]
#
# Produce a 2-panel figure from scratch:
# - Panel 1: MM curve with Km and Vmax annotated; simulated data points overlaid
# - Panel 2: Three inhibition models (no inhibitor, competitive, non-competitive) on one axes
#
# Annotate axes, title, and legend. Save to the scratchpad (not portfolio — assessment only).

# %%
# B3 implementation here
# Use: Vmax=10, Km=2, I=4, Ki=3
# Your code here

# %% [markdown]
# ---
# ## Section C — Applied Analysis (4 points)
#
# **C1 [4 pts]:** You are given Western blot data from a cancer cell line treated with
# vemurafenib (BRAF inhibitor). The blot shows:
# - BRAF: no change (band at 100 kDa)
# - p-MEK (phospho-MEK): 80% reduction after 1h
# - p-ERK (phospho-ERK): 40% reduction after 1h
# - p-ERK: rebounds to 90% of baseline after 24h
#
# Answer (in written form):
# - (a) Why is BRAF protein level unchanged even though vemurafenib is a BRAF inhibitor?
# - (b) Why does p-MEK drop more than p-ERK at 1h?
# - (c) What biological mechanism explains the ERK rebound at 24h?
# - (d) A Western blot is not quantitative by default. What protocol step makes it
#   semi-quantitative, and what antibody is needed as a control?

# %% [markdown]
# > *[Written answers for C1(a)–(d) here]*

# %% [markdown]
# ---
# ## Section D — Mock Interview (2 points, 1 pt each)
#
# **D1.** "A collaborator says their protein is at 45 kDa on their Western blot but
# the predicted MW is 28 kDa. Can you explain this?"
#
# > *[Your answer — 3–5 sentences, as in a real interview]*
#
# ---
#
# **D2.** "Explain what Km means and why it matters for drug development."
#
# > *[Your answer — 3–5 sentences. This is the most common biochemistry interview
# > question for computational biologist roles at biotech and pharma.]*

# %% [markdown]
# ---
# ## Self-scoring guide
#
# | Section | Points | Your score |
# |---------|--------|------------|
# | A — Conceptual (6 × 2 pts) | 12 | __ /12 |
# | B1 — MM + competitive inhibition | 5 | __ /5 |
# | B2 — Molecular weight | 3 | __ /3 |
# | B3 — Kinetics figure | 4 | __ /4 |
# | C — Applied | 4 | __ /4 |
# | D — Interview | 2 | __ /2 |
# | **Total** | **30** | **__ /30** |
#
# **Pass:** 24/30 (80%).
#
# If you scored < 24: identify the weak section and revisit those notebooks.
# The most common weak points at Tier 2 for this module are:
# - Confusing competitive vs. non-competitive inhibition (revisit NB03)
# - Forgetting that Km is the substrate concentration at Vmax/2, not the affinity constant Kd
# - Not knowing which repair pathway is mutated in Lynch syndrome (revisit NB04)
#
# ---
# ## Module 07 Complete
#
# **Date completed:** ____________________
# **Score:** __ / 30
# **Weak areas to revisit before Module 10 (Transcriptomics/Proteomics):** ____________________
#
# → Next: **Module 08 — Bioinformatics: Sequence Analysis** (Tier 1)
