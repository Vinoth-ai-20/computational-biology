# %% [markdown]
# # Notebook 17 — Paper Reading Session (Three-Pass Template)
#
# **Module:** 05 — Biology Fundamentals
# **Notebook:** 17 of 18
# **Purpose:** Template for structured paper reading using the Three-Pass Method
# **Time estimate:** 2–4 hours per paper
#
# > This template is used for *every* paper read in this module. Make a copy for
# > each paper. The completed files live in `paper-notes/`. This file is the blank template.
# >
# > **Track A connection:** Pass 3 (reconstruct unaided) is direct interview rehearsal.
# > The most common bioinformatics interview task: being handed a paper and asked to
# > explain it back in plain language.

# %% [markdown]
# ---
# ## Paper Metadata
#
# | Field | Value |
# |-------|-------|
# | **Title** | *(fill in)* |
# | **Authors** | *(fill in)* |
# | **Journal / Year** | *(fill in)* |
# | **DOI** | *(fill in)* |
# | **Why reading this** | *(fill in: is it foundational? directly relevant to a module? interview prep?)* |
# | **Prerequisite concepts** | *(what do you need to know before reading this well?)* |

# %% [markdown]
# ---
# ## Pass 1 — Skim (5–10 minutes)
#
# Read: title, abstract, introduction (first and last paragraph), conclusion, all figures and
# their captions. Do not read the methods or results body.
#
# **After the skim, answer these from memory:**
#
# 1. **What is the research question?**
#    > *(your answer)*
#
# 2. **What is the main claim?**
#    > *(one sentence)*
#
# 3. **What type of evidence do they use?** (experimental / computational / statistical / review)
#    > *(your answer)*
#
# 4. **What are the key figures?** (List 2–3 figures that would need to be understood to evaluate the claim)
#    > *(e.g. Figure 2A, Figure 3B, Figure 5)*
#
# 5. **Pass 1 confidence score:** ☐ 0 ☐ 1 ☐ 2 ☐ 3
#    (0=confused, 1=rough idea, 2=clear on the claim, 3=could discuss it right now)

# %% [markdown]
# ---
# ## Pass 2 — Intent (45–90 minutes)
#
# Read the paper fully but quickly. Note: methods overview, key results, any tables,
# where you feel uncertain. Do not get stuck — mark fuzzy parts with `[?]` and keep moving.
#
# **Fuzzy points (fill in as you read):**
#
# | Page / Section | What's unclear | Resolved by (notebook, paper, ask) |
# |---------------|----------------|------------------------------------|
# | | | |
# | | | |
#
# **Methods summary (in your own words):**
# > *(2–4 sentences: what data, what method, what analysis)*
#
# **Key results (in your own words):**
# > *(2–4 sentences: what was found, in which figure, with what magnitude of effect)*
#
# **One thing I would critique:**
# > *(a limitation, a missing control, an alternative interpretation)*
#
# **Pass 2 confidence score:** ☐ 0 ☐ 1 ☐ 2 ☐ 3

# %% [markdown]
# ---
# ## Pass 3 — Reconstruct (1–2 hours; paper closed)
#
# > Close the paper. Do not look at it. Answer all questions below from memory.
# > Write what you actually recall — not what you think you should say.
#
# **1. Explain the paper in 3 sentences to a non-specialist:**
# > *(your answer)*
#
# **2. Explain the core method in your own words:**
# > *(your answer)*
#
# **3. Re-derive or re-implement the central result:**
# > *(can be a sketch, equation, or code cell below)*
#
# **4. What is the key figure, and what would you say about it in an interview?**
# > *(your answer)*
#
# **5. How would you follow up this work? What is the next obvious experiment?**
# > *(your answer)*
#
# **Pass 3 succeeded unaided:** ☐ Yes ☐ Partially ☐ No (had to re-read)
#
# **Pass 3 confidence score:** ☐ 0 ☐ 1 ☐ 2 ☐ 3

# %%
# Pass 3 — Re-implementation cell
# If the paper has a key equation or computational method,
# implement it here from memory (paper closed)

import numpy as np
import matplotlib.pyplot as plt

# YOUR IMPLEMENTATION HERE
print("Pass 3 reconstruction: implement the paper's core method here.")
print("If the method is too complex for one sitting, implement a simplified version.")

# %% [markdown]
# ---
# ## Module 05 Suggested Papers (choose at least one)
#
# Pick one paper from the module's `papers.md` for this session:
#
# | Paper | Why to read it | Difficulty |
# |-------|---------------|------------|
# | Watson & Crick (1953) — DOI: 10.1038/171737a0 | 1 page; foundational; the DNA double helix | ★☆☆ |
# | Hardy (1908) — DOI: 10.1126/science.28.706.49 | 2 pages; the Hardy-Weinberg derivation | ★☆☆ |
# | Kimura (1968) — DOI: 10.1038/217624a0 | 3 pages; neutral theory of molecular evolution | ★★☆ |
# | ENCODE Consortium (2012) — DOI: 10.1038/nature11247 | Seminal; 80% of genome is functional | ★★★ |
#
# **Recommended first paper:** Watson & Crick (1953) — 1 page, foundational, directly
# relevant to central dogma (NB03), and referenced in virtually every genomics talk.
#
# ---
# ## Logging
#
# After completing a paper, add one line to `paper-notes/module05_paper_log.md`:
#
# ```
# | YYYY-MM-DD | Paper title | DOI | Pass 3 unaided? | Score |
# ```
#
# ---
# *Next: `18_module_assessment_mock_interview.ipynb`*
