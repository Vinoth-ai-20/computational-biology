# %% [markdown]
# # Notebook 12 — Module 06 Assessment
#
# **Module:** 06 — Genetics and Evolution
# **Notebook:** 12 of 12 (final)
# **Passing threshold:** 32/40 points (80%)
# **Time limit:** 90 minutes
# **Rules:** Closed-notebook for Sections A and B. Open-notebook for Section C only.
#
# ---
#
# > **Instructions:**
# > 1. Complete Section A (conceptual) in a separate markdown cell — write answers in
# >    plain English, no code.
# > 2. Complete Section B (implementation) in the provided empty code cells.
# >    Implement from memory. No copying from previous notebooks.
# > 3. Section C (applied analysis) may use any module resources.
# > 4. Section D (mock interview) — write as if speaking to a hiring panel or
# >    PhD interview committee.
# > 5. Submit the completed notebook to Claude for Section B review.

# %% [markdown]
# ---
# ## Section A — Conceptual Questions (16 points, 2 pts each)
#
# **Instructions:** Answer each question in 2–4 sentences. No code.
#
# **A1.** What is the Haldane mapping function? What problem does it solve that a simple
# linear map between cM and recombination fraction cannot?
#
# > *[Your answer here]*
#
# ---
#
# **A2.** Define D and r² (LD statistics). Which is more useful for GWAS imputation,
# and why?
#
# > *[Your answer here]*
#
# ---
#
# **A3.** What is the difference between a transition and a transversion? Why is Ti/Tv
# useful as a quality metric in variant calling?
#
# > *[Your answer here]*
#
# ---
#
# **A4.** State Kimura's fixation probability formula. What does it reduce to for
# a neutral allele (s = 0)?
#
# > *[Your answer here]*
#
# ---
#
# **A5.** What is Tajima's D? Interpret D = −1.8 and D = +1.2 in biological terms.
#
# > *[Your answer here]*
#
# ---
#
# **A6.** Explain the coalescent in one paragraph. What is the MRCA, and how does Nₑ
# affect E[T_MRCA]?
#
# > *[Your answer here]*
#
# ---
#
# **A7.** What is the key difference between UPGMA and Neighbour-Joining? When would
# UPGMA give the wrong topology?
#
# > *[Your answer here]*
#
# ---
#
# **A8.** What is an Evolutionarily Stable Strategy? Describe the Hawk-Dove ESS for
# V = 5, C = 20.
#
# > *[Your answer here]*

# %% [markdown]
# ---
# ## Section B — Implementation (16 points)
#
# **Rules:** Implement from memory. No imports beyond NumPy. Do not import from
# previous notebooks.
#
# ### B1 — `haldane_theta(d_morgans)` and `ld_statistics(haplotype_counts)` [5 points]
#
# - `haldane_theta(d_morgans)` → recombination fraction (2 pts)
# - `ld_statistics(haplotype_counts)` → dict with D, r², p_A, p_B (3 pts)
# - Test: verify haldane_theta(0.5) ≈ 0.432; verify ld_statistics({'AB':400,'Ab':0,'aB':0,'ab':600}) gives r²=1.0

# %%
import numpy as np

# Implement here:
def haldane_theta(d_morgans):
    pass  # TODO

def ld_statistics(haplotype_counts):
    pass  # TODO

# Tests — these should all pass before submitting
print("B1 tests:")
print(f"  haldane_theta(0.5): {haldane_theta(0.5):.4f}  (expected: 0.4323)")
print(f"  haldane_theta(0.0): {haldane_theta(0.0):.4f}  (expected: 0.0)")
r = ld_statistics({'AB':400,'Ab':0,'aB':0,'ab':600})
if r: print(f"  perfect LD r²: {r.get('r2', '?'):.4f}  (expected: 1.0)")
r2 = ld_statistics({'AB':240,'Ab':160,'aB':360,'ab':240})
if r2: print(f"  equilibrium D: {r2.get('D', '?'):.4f}  (expected: 0.0)")

# %% [markdown]
# ### B2 — `kimura_fixation_prob(p0, s, Ne)` [4 points]
#
# - Implement the Kimura (1962) fixation probability formula
# - Handle the neutral case (s ≈ 0) correctly
# - Verify: for p0=0.01, s=0, Ne=1000 → P_fix = 0.01

# %%
def kimura_fixation_prob(p0, s, Ne):
    pass  # TODO

# Tests
print("B2 tests:")
p = kimura_fixation_prob(0.01, 0.0, 1000)
print(f"  Neutral (s=0, p0=0.01): {p}  (expected: 0.01)")
p2 = kimura_fixation_prob(1/(2*500), 0.01, 500)
print(f"  New beneficial (s=0.01, Ne=500): {p2:.5f}  (expected ≈ 0.02)")
p3 = kimura_fixation_prob(0.5, -0.05, 500)
print(f"  Deleterious (s=-0.05, p0=0.5): {p3:.6f}  (expected ≈ 0.0)")

# %% [markdown]
# ### B3 — `tajimas_d(sequences)` + 2-panel figure [7 points]
#
# - Implement Tajima's D from scratch (3 pts)
#   - Correctly compute θ_π and θ_W
#   - Correct variance formula (use a1, a2, e1, e2)
# - Plot 2-panel figure (4 pts):
#   - Panel 1: Tajima's D under neutral simulation (should be near 0)
#   - Panel 2: Compare D for sequences simulated with many common variants (D>0)
#     vs. many rare variants (D<0)
# - Both axes must be labelled; legend included

# %%
import matplotlib.pyplot as plt

def tajimas_d(sequences):
    """sequences: list of aligned strings"""
    pass  # TODO

# Sequence simulation helper (this one is provided — do not modify)
def make_sequences(n, L, n_mutations, rare_variants=False, seed=42):
    rng = np.random.default_rng(seed)
    ancestor = rng.choice(list('ACGT'), L)
    seqs = [ancestor.copy() for _ in range(n)]
    for _ in range(n_mutations):
        pos = rng.integers(L)
        if rare_variants:
            n_affected = rng.integers(1, 3)  # 1-2 individuals: rare variants
        else:
            n_affected = rng.integers(n//2, n)  # many individuals: common variants
        affected = rng.choice(n, n_affected, replace=False)
        alt = rng.choice([b for b in 'ACGT' if b != str(seqs[0][pos])])
        for i in affected:
            seqs[i][pos] = alt
    return [''.join(s) for s in seqs]

# Implement the figure here after implementing tajimas_d
fig, axes = plt.subplots(1, 2, figsize=(12, 4))
# ... your code here ...
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# ## Section C — Applied Analysis (4 points, open-notebook)
#
# **C1 [4 pts]:** A GWAS of height identifies a significant SNP at chromosome 6q24
# with p = 3.2×10⁻⁹. The tag SNP has r² = 0.91 with a missense variant in gene HMGA1.
# The per-allele effect size is β = 0.4 cm.
#
# - (a) Is this SNP likely the causal variant? What additional evidence would strengthen
#   the causal interpretation?
# - (b) The tag SNP has minor allele frequency MAF = 0.23. Using HWE, how many
#   heterozygotes would you expect in a sample of 5,000 individuals?
# - (c) You want to test if this GWAS locus is under positive selection. Which
#   evolutionary test would you apply, and what would a positive result look like?

# %%
# C1(b) — HWE heterozygote count
maf = 0.23
n = 5000

# Your calculation here:
# expected_het = ...

# %% [markdown]
# > *[Written answers for C1(a) and C1(c) here]*

# %% [markdown]
# ---
# ## Section D — Mock Interview (4 points, 1 pt each)
#
# **Instructions:** Write exactly as you would speak in a 5-minute interview slot.
# No bullet points — complete sentences. Show reasoning, not just facts.
#
# **D1.** "We've sequenced a population of bacteria from a patient before and after
# antibiotic treatment. How would you determine whether the resistance allele spread
# by positive selection or by chance?"
#
# > *[Your answer — aim for 4–6 sentences]*
#
# ---
#
# **D2.** "Explain what the coalescent tells us about the effective population size
# of humans."
#
# > *[Your answer — aim for 4–6 sentences]*
#
# ---
#
# **D3.** "A phylogenetic tree built with UPGMA shows pandas as the outgroup to all
# other bears. You're suspicious of this result. What would you check?"
#
# > *[Your answer — aim for 4–6 sentences]*
#
# ---
#
# **D4.** "You compute dN/dS = 0.08 for a conserved enzyme. The next gene in the same
# pathway has dN/dS = 1.4. What does this contrast suggest?"
#
# > *[Your answer — aim for 4–6 sentences]*

# %% [markdown]
# ---
# ## Self-scoring guide
#
# | Section | Points | Your score |
# |---------|--------|------------|
# | A — Conceptual (8 × 2 pts) | 16 | __ /16 |
# | B1 — Haldane + LD | 5 | __ /5 |
# | B2 — Kimura fixation | 4 | __ /4 |
# | B3 — Tajima's D + figure | 7 | __ /7 |
# | C — Applied | 4 | __ /4 |
# | D — Interview | 4 | __ /4 |
# | **Total** | **40** | **__ /40** |
#
# **Pass:** 32/40 (80%)
#
# If you scored < 32, identify the weakest section and revise those notebooks before
# moving to Module 07. Do not continue until the pass threshold is met — this is
# the gate for Track A interview readiness on Module 06 material.
#
# ---
# ## Module 06 Complete
#
# **Date completed:** ____________________
# **Score:** __ / 40
# **Notes on weak areas:** ____________________
#
# → Next module: **07 — Biochemistry and Molecular Biology**
