# %% [markdown]
# # Assignment A01 — Expression Matrix Pipeline
#
# **Module:** 01 — Python & Scientific Computing
# **Type:** Assignment (less scaffolded than notebooks)
# **Prerequisites:** Notebooks 01–10 complete
# **Time estimate:** 3–5 hours

# %% [markdown]
# ---
# ## Objective
#
# Download a small public GEO expression dataset, clean it, normalize it, and produce
# a labeled heatmap and PCA scatter plot using `compbio_utils`.
#
# This assignment is the first full analysis pipeline using real biological data.
# It must run reproducibly from a clean clone.

# %% [markdown]
# ---
# ## Step 1 — Data Acquisition
#
# Choose a small (≤ 20 samples, ≤ 10,000 genes) GEO dataset with a clear
# case/control design. Document the accession below.
#
# **GEO Accession:** ____________________
# **Organism:** ____________________
# **Conditions:** ____________________
# **n samples:** ____________________

# %%
# Fetch the dataset (use GEOparse or manual download)
# Document how to re-fetch in datasets/README.md
import pathlib

repo_root = pathlib.Path.cwd()
while repo_root != repo_root.parent:
    if (repo_root / ".git").exists(): break
    repo_root = repo_root.parent

raw_dir = repo_root / "curriculum" / "01_python_scientific_computing" / "datasets" / "raw"
raw_dir.mkdir(parents=True, exist_ok=True)
print(f"Raw data dir: {raw_dir}")

# %% [markdown]
# ---
# ## Step 2 — Data Cleaning
#
# Apply `compbio_utils.io.clean_expression_matrix()`. Document every filtering decision.

# %%
# Your cleaning code here
# Requirements:
# 1. Report shape before and after each cleaning step
# 2. Justify each threshold chosen (min_count, min_samples, mad_threshold)
# 3. Save the clean matrix to datasets/processed/
pass

# %% [markdown]
# ---
# ## Step 3 — Normalization

# %%
# Apply CPM + log2 normalization using compbio_utils.stats
# Report: value range before/after, any unexpected values
pass

# %% [markdown]
# ---
# ## Step 4 — Visualization

# %%
# Produce:
# 1. Expression heatmap (top 50 most variable genes) using compbio_utils.plotting
# 2. PCA scatter plot coloured by condition using compbio_utils.plotting
# Save to portfolio/A01_geo_expression_analysis.png
pass

# %% [markdown]
# ---
# ## Submission Checklist
#
# - [ ] GEO accession documented in this notebook and in `datasets/README.md`
# - [ ] Cleaning decisions justified inline
# - [ ] Cleaned matrix saved to `datasets/processed/`
# - [ ] Both figures produced and saved
# - [ ] Notebook runs top-to-bottom in a clean kernel without errors
# - [ ] All code uses `compbio_utils` functions, not inline re-implementations
#
# ---
# ## Reflection
#
# **Date completed:** ____________________
#
# > *[What was the most time-consuming step? What would you do differently on the next dataset? Did the PCA reveal anything about sample quality?]*
